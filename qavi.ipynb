# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("telemetry_abdulqavi.csv")

# %%
df.head()
# Out:
#    1  A1 A1.1 A1.2 A1.3 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0  2  A2   A2   A2   A2        NaN        NaN        NaN        NaN
# 1  3  A1   A1  NaN  NaN        NaN        NaN        NaN        NaN
# 2  4  A2   A2   A1   A1         A1         A1         A3         A1
# 3  5  A1   A1   A1   A1         A1         A1        NaN        NaN
# 4  6  A4   A1   A1   A2         A1         A4         A5         A6
#
#   Unnamed: 9  ... Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20  \
# 0        NaN  ...         NaN         NaN         NaN         NaN         NaN
# 1        NaN  ...         NaN         NaN         NaN         NaN         NaN
# 2        NaN  ...         NaN         NaN         NaN         NaN         NaN
# 3        NaN  ...         NaN         NaN         NaN         NaN         NaN
# 4         A5  ...         NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 21 Unnamed: 22 Unnamed: 23 Unnamed: 24 Unnamed: 25
# 0         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN
#
# [5 rows x 26 columns]

# %%
df.set_index(df.columns[0],inplace=True)

# %%
df.head()
# Out:
#    A1 A1.1 A1.2 A1.3 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 1
# 2  A2   A2   A2   A2        NaN        NaN        NaN        NaN        NaN
# 3  A1   A1  NaN  NaN        NaN        NaN        NaN        NaN        NaN
# 4  A2   A2   A1   A1         A1         A1         A3         A1        NaN
# 5  A1   A1   A1   A1         A1         A1        NaN        NaN        NaN
# 6  A4   A1   A1   A2         A1         A4         A5         A6         A5
#
#   Unnamed: 10  ... Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19  \
# 1              ...
# 2         NaN  ...         NaN         NaN         NaN         NaN
# 3         NaN  ...         NaN         NaN         NaN         NaN
# 4         NaN  ...         NaN         NaN         NaN         NaN
# 5         NaN  ...         NaN         NaN         NaN         NaN
# 6          A4  ...         NaN         NaN         NaN         NaN
#
#   Unnamed: 20 Unnamed: 21 Unnamed: 22 Unnamed: 23 Unnamed: 24 Unnamed: 25
# 1
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
# 5         NaN         NaN         NaN         NaN         NaN         NaN
# 6         NaN         NaN         NaN         NaN         NaN         NaN
#
# [5 rows x 25 columns]

# %%
data=[]
for i in range(66):
    x=df.values[i]
    x=x[~pd.isnull(x)]
    data.append(x)
data
# Out:
# [array(['A2', 'A2', 'A2', 'A2'], dtype=object),
#  array(['A1', 'A1'], dtype=object),
#  array(['A2', 'A2', 'A1', 'A1', 'A1', 'A1', 'A3', 'A1'], dtype=object),
#  array(['A1', 'A1', 'A1', 'A1', 'A1', 'A1'], dtype=object),
#  array(['A4', 'A1', 'A1', 'A2', 'A1', 'A4', 'A5', 'A6', 'A5', 'A4', 'A1',
#         'A1'], dtype=object),
#  array(['A1', 'A7', 'A8', 'A9', 'A10', 'A11', 'A12', 'A11', 'A4', 'A13',
#         'A7', 'A1', 'A1'], dtype=object),
#  array(['A1', 'A1', 'A1'], dtype=object),
#  array(['A1', 'A1', 'A5', 'A1'], dtype=object),
#  array(['A1', 'A1'], dtype=object),
#  array(['A1', 'A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1', 'A1'], dtype=object),
#  array(['A14', 'A15', 'A16', 'A16', 'A1', 'A1', 'A1'], dtype=object),
#  array(['A1', 'A17', 'A18', 'A13', 'A5', 'A1'], dtype=object),
#  array(['A19', 'A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A5', 'A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A4', 'A1'], dtype=object),
#  array(['A20', 'A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A21', 'A22', 'A2', 'A1'], dtype=object),
#  array(['A1', 'A1', 'A20', 'A20', 'A1', 'A10', 'A20', 'A1', 'A20', 'A8',
#         'A8', 'A8', 'A20', 'A1', 'A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A10', 'A7', 'A23', 'A15', 'A23', 'A23', 'A23', 'A7', 'A1'],
#        dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A2', 'A4', 'A1', 'A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1', 'A1', 'A20', 'A1', 'A1'], dtype=object),
#  array(['A19', 'A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A17', 'A19', 'A24', 'A22', 'A25', 'A17', 'A3', 'A16', 'A1', 'A1',
#         'A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A7', 'A1', 'A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A26', 'A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A26', 'A26', 'A27', 'A1', 'A1', 'A1'], dtype=object),
#  array(['A4', 'A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A5', 'A17', 'A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A4', 'A4', 'A4', 'A4', 'A12', 'A4', 'A23', 'A23', 'A4', 'A15',
#         'A15', 'A9', 'A9', 'A9', 'A9', 'A9', 'A9', 'A9', 'A4', 'A20',
#         'A20', 'A28', 'A4', 'A9', 'A9'], dtype=object),
#  array(['A1'], dtype=object),
#  array([], dtype=object)]

# %%
from markovclick.models import MarkovClickstream
m = MarkovClickstream(data)

# %%
fig, ax = plt.subplots(figsize=(20,10))
sns.heatmap(m.prob_matrix, xticklabels=m.pages, yticklabels=m.pages)

# %%
from markovclick.viz import visualise_markov_chain
graph = visualise_markov_chain(m)

# %%
print(graph.source)
# Out:
# digraph {
# 	A1 [label=A1 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A1 -> A1 [label=0.75 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A1 -> A20 [label="   0.07" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A10 [label=A10 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A10 -> A20 [label=0.33 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A10 -> A7 [label="   0.33" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A10 -> A10 [label="   0.00" arrowsize=0.5 color="#cfd8dc" fontname=Helvetica fontsize=10 penwidth=1.8]
# 	A11 [label=A11 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A11 -> A12 [label=0.50 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A11 -> A4 [label="   0.50" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A11 -> A11 [label="   0.00" arrowsize=0.5 color="#cfd8dc" fontname=Helvetica fontsize=10 penwidth=1.8]
# 	A12 [label=A12 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A12 -> A11 [label=0.50 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A12 -> A4 [label="   0.50" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A12 -> A12 [label="   0.00" arrowsize=0.5 color="#cfd8dc" fontname=Helvetica fontsize=10 penwidth=1.8]
# 	A13 [label=A13 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A13 -> A7 [label=0.50 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A13 -> A5 [label="   0.50" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A13 -> A13 [label="   0.00" arrowsize=0.5 color="#cfd8dc" fontname=Helvetica fontsize=10 penwidth=1.8]
# 	A14 [label=A14 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A14 -> A15 [label=1.00 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A14 -> A9 [label="   0.00" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A14 -> A14 [label="   0.00" arrowsize=0.5 color="#cfd8dc" fontname=Helvetica fontsize=10 penwidth=1.8]
# 	A15 [label=A15 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A15 -> A9 [label=0.25 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A15 -> A15 [label="   0.25" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A16 [label=A16 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A16 -> A1 [label=0.67 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A16 -> A16 [label="   0.33" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A17 [label=A17 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A17 -> A1 [label=0.25 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A17 -> A3 [label="   0.25" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A17 -> A17 [label="   0.00" arrowsize=0.5 color="#cfd8dc" fontname=Helvetica fontsize=10 penwidth=1.8]
# 	A18 [label=A18 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A18 -> A13 [label=1.00 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A18 -> A9 [label="   0.00" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A18 -> A18 [label="   0.00" arrowsize=0.5 color="#cfd8dc" fontname=Helvetica fontsize=10 penwidth=1.8]
# 	A19 [label=A19 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A19 -> A1 [label=0.67 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A19 -> A24 [label="   0.33" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A19 -> A19 [label="   0.00" arrowsize=0.5 color="#cfd8dc" fontname=Helvetica fontsize=10 penwidth=1.8]
# 	A2 [label=A2 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A2 -> A2 [label=0.50 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A2 -> A1 [label="   0.38" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A20 [label=A20 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A20 -> A1 [label=0.56 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A20 -> A20 [label="   0.22" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A21 [label=A21 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A21 -> A22 [label=1.00 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A21 -> A9 [label="   0.00" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A21 -> A21 [label="   0.00" arrowsize=0.5 color="#cfd8dc" fontname=Helvetica fontsize=10 penwidth=1.8]
# 	A22 [label=A22 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A22 -> A25 [label=0.50 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A22 -> A2 [label="   0.50" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A22 -> A22 [label="   0.00" arrowsize=0.5 color="#cfd8dc" fontname=Helvetica fontsize=10 penwidth=1.8]
# 	A23 [label=A23 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A23 -> A23 [label=0.50 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A23 -> A7 [label="   0.17" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A24 [label=A24 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A24 -> A22 [label=1.00 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A24 -> A9 [label="   0.00" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A24 -> A24 [label="   0.00" arrowsize=0.5 color="#cfd8dc" fontname=Helvetica fontsize=10 penwidth=1.8]
# 	A25 [label=A25 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A25 -> A17 [label=1.00 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A25 -> A9 [label="   0.00" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A25 -> A25 [label="   0.00" arrowsize=0.5 color="#cfd8dc" fontname=Helvetica fontsize=10 penwidth=1.8]
# 	A26 [label=A26 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A26 -> A1 [label=0.33 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A26 -> A27 [label="   0.33" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A26 -> A26 [label="   0.33" arrowsize=0.5 color="#cfd8dc" fontname=Helvetica fontsize=10 penwidth=1.8]
# 	A27 [label=A27 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A27 -> A1 [label=1.00 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A27 -> A8 [label="   0.00" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A27 -> A27 [label="   0.00" arrowsize=0.5 color="#cfd8dc" fontname=Helvetica fontsize=10 penwidth=1.8]
# 	A28 [label=A28 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A28 -> A4 [label=1.00 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A28 -> A9 [label="   0.00" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A28 -> A28 [label="   0.00" arrowsize=0.5 color="#cfd8dc" fontname=Helvetica fontsize=10 penwidth=1.8]
# 	A3 [label=A3 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A3 -> A1 [label=0.50 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A3 -> A16 [label="   0.50" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A3 -> A3 [label="   0.00" arrowsize=0.5 color="#cfd8dc" fontname=Helvetica fontsize=10 penwidth=1.8]
# 	A4 [label=A4 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A4 -> A1 [label=0.33 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A4 -> A4 [label="   0.20" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A5 [label=A5 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A5 -> A1 [label=0.50 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A5 -> A6 [label="   0.17" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A5 -> A5 [label="   0.00" arrowsize=0.5 color="#cfd8dc" fontname=Helvetica fontsize=10 penwidth=1.8]
# 	A6 [label=A6 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A6 -> A5 [label=1.00 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A6 -> A9 [label="   0.00" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A6 -> A6 [label="   0.00" arrowsize=0.5 color="#cfd8dc" fontname=Helvetica fontsize=10 penwidth=1.8]
# 	A7 [label=A7 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A7 -> A1 [label=0.60 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A7 -> A23 [label="   0.20" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A7 -> A7 [label="   0.00" arrowsize=0.5 color="#cfd8dc" fontname=Helvetica fontsize=10 penwidth=1.8]
# 	A8 [label=A8 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A8 -> A8 [label=0.50 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A8 -> A9 [label="   0.25" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A9 [label=A9 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A9 -> A9 [label=0.78 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A9 -> A10 [label="   0.11" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# }

# %%
graph.render('test-output/round-tabl.gv', view=True)
# Out:
# 'test-output\\round-tabl.gv.pdf'

# %%
graph
